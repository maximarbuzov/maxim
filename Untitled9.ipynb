# %% [markdown]
# <a href="https://colab.research.google.com/github/maximarbuzov/maxim/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#  Fertility.csv, Life_Table1.csv, Life_Table2.csv, Population.csv, Population2.csv, Population3.csv, Population4.csv, Population5.csv

# %%
data1=pd.read_csv("http://intersyn.net/Fertility.csv")
# Out:
# <ipython-input-3-788ca429c9c1>:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1=pd.read_csv("http://intersyn.net/Fertility.csv")

# %%
data1.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
# 3          1    900   NaN       NaN       NaN        1.0          1
# 4          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  VarID Variant  Time  MidPeriod  AgeGrp  \
# 0       World         0    World      2  Medium  1950     1950.5      15
# 1       World         0    World      2  Medium  1950     1950.5      16
# 2       World         0    World      2  Medium  1950     1950.5      17
# 3       World         0    World      2  Medium  1950     1950.5      18
# 4       World         0    World      2  Medium  1950     1950.5      19
#
#    AgeGrpStart  AgeGrpSpan     ASFR  PASFR    Births
# 0           15           1   30.809  0.634   747.345
# ...

# %%
data2=pd.read_csv("http://intersyn.net/Life_Table1.csv")
# Out:
# <ipython-input-6-d3139451d135>:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2=pd.read_csv("http://intersyn.net/Life_Table1.csv")

# %%
data2.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
# 3          1    900   NaN       NaN       NaN        1.0          1
# 4          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  ...        mx        qx        px  \
# 0       World         0    World  ...  0.159391  0.143387  0.856613
# 1       World         0    World  ...  0.043620  0.042689  0.957311
# 2       World         0    World  ...  0.025708  0.025381  0.974619
# 3       World         0    World  ...  0.017162  0.017016  0.982984
# 4       World         0    World  ...  0.012348  0.012272  0.987728
#
#            lx         dx         Lx        Sx           Tx       ex       ax
# ...

# %%
data3=pd.read_csv("http://intersyn.net/Life_Table2.csv")
# Out:
# <ipython-input-8-7d253f412b63>:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data3=pd.read_csv("http://intersyn.net/Life_Table2.csv")

# %%
data3.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
# 3          1    900   NaN       NaN       NaN        1.0          1
# 4          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  ...        mx        qx        px  \
# 0       World         0    World  ...  0.028174  0.027528  0.972472
# 1       World         0    World  ...  0.003599  0.003593  0.996407
# 2       World         0    World  ...  0.002476  0.002473  0.997527
# 3       World         0    World  ...  0.001951  0.001949  0.998051
# 4       World         0    World  ...  0.001618  0.001617  0.998383
#
#            lx        dx         Lx        Sx           Tx       ex        ax
# ...

# %%
data4=pd.read_csv("http://intersyn.net/Population.csv")
# Out:
# <ipython-input-10-ef0760f51758>:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data4=pd.read_csv("http://intersyn.net/Population.csv")

# %%
data4.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
# 3          1    900   NaN       NaN       NaN        1.0          1
# 4          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  VarID Variant  Time  MidPeriod AgeGrp  \
# 0       World         0    World      2  Medium  1950       1950      0
# 1       World         0    World      2  Medium  1950       1950      1
# 2       World         0    World      2  Medium  1950       1950      2
# 3       World         0    World      2  Medium  1950       1950      3
# 4       World         0    World      2  Medium  1950       1950      4
#
#    AgeGrpStart  AgeGrpSpan    PopMale  PopFemale   PopTotal
# 0            0           1  41312.322  39439.289  80751.611
# ...

# %%
data5=pd.read_csv("http://intersyn.net/Population2.csv")
# Out:
# <ipython-input-12-77adea347165>:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data5=pd.read_csv("http://intersyn.net/Population2.csv")

# %%
data5.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
# 3          1    900   NaN       NaN       NaN        1.0          1
# 4          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  VarID Variant  Time  MidPeriod AgeGrp  \
# 0       World         0    World      3    High  2022       2022    0-4
# 1       World         0    World      3    High  2022       2022    5-9
# 2       World         0    World      3    High  2022       2022  10-14
# 3       World         0    World      3    High  2022       2022  15-19
# 4       World         0    World      3    High  2022       2022  20-24
#
#    AgeGrpStart  AgeGrpSpan     PopMale   PopFemale    PopTotal
# ...

# %%
data6=pd.read_csv("http://intersyn.net/Population3.csv")
# Out:
# <ipython-input-14-e0b97670a62f>:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data6=pd.read_csv("http://intersyn.net/Population3.csv")

# %%
data6.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
# 3          1    900   NaN       NaN       NaN        1.0          1
# 4          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  VarID Variant  Time  MidPeriod AgeGrp  \
# 0       World         0    World      3    High  2022       2022    0-4
# 1       World         0    World      3    High  2022       2022    5-9
# 2       World         0    World      3    High  2022       2022  10-14
# 3       World         0    World      3    High  2022       2022  15-19
# 4       World         0    World      3    High  2022       2022  20-24
#
#    AgeGrpStart  AgeGrpSpan     PopMale   PopFemale    PopTotal
# ...

# %%
data7=pd.read_csv("http://intersyn.net/Population4.csv")
# Out:
# <ipython-input-16-bc866deb3623>:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data7=pd.read_csv("http://intersyn.net/Population4.csv")

# %%
data7.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
# 3          1    900   NaN       NaN       NaN        1.0          1
# 4          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  VarID Variant  Time  MidPeriod AgeGrp  \
# 0       World         0    World      2  Medium  1950       1950      0
# 1       World         0    World      2  Medium  1950       1950      1
# 2       World         0    World      2  Medium  1950       1950      2
# 3       World         0    World      2  Medium  1950       1950      3
# 4       World         0    World      2  Medium  1950       1950      4
#
#    AgeGrpStart  AgeGrpSpan  PopMale  PopFemale  PopTotal
# 0            0           1    1.672      1.598     3.269
# ...

# %%
data8=pd.read_csv("http://intersyn.net/Population5.csv")
# Out:
# <ipython-input-18-92fd567fe507>:1: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data8=pd.read_csv("http://intersyn.net/Population5.csv")

# %%
data8.head()
# Out:
#    SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0          1    900   NaN       NaN       NaN        1.0          1
# 1          1    900   NaN       NaN       NaN        1.0          1
# 2          1    900   NaN       NaN       NaN        1.0          1
# 3          1    900   NaN       NaN       NaN        1.0          1
# 4          1    900   NaN       NaN       NaN        1.0          1
#
#   LocTypeName  ParentID Location  VarID Variant  Time  MidPeriod AgeGrp  \
# 0       World         0    World      2  Medium  2022       2022      0
# 1       World         0    World      2  Medium  2022       2022      1
# 2       World         0    World      2  Medium  2022       2022      2
# 3       World         0    World      2  Medium  2022       2022      3
# 4       World         0    World      2  Medium  2022       2022      4
#
#    AgeGrpStart  AgeGrpSpan  PopMale  PopFemale  PopTotal
# 0            0           1    0.842      0.799     1.641
# ...
