# %% [markdown]
# <a href="https://colab.research.google.com/github/maximarbuzov/maxim/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %%
data=pd.read_csv("data.csv")

# %%
data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  class           32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.corr()
# Out:
# <ipython-input-6-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# ...

# %%
data['age'].value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: age, Length: 73, dtype: int64

# %%
data['age'].unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87])

# %%
data['age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(data=data['age'],bins=100,kde=True,color='skyblue')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
data['class'].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: class, dtype: int64

# %%
from scipy.stats.contingency import chi2_contingency

# %%
#Ho - статистически значимая связь между полом и уровнем дохода отсутствует
contingency_table=pd.crosstab(data['sex'],data['class'])

# %%
contingency_table.head()
# Out:
# class     <=50K   >50K
# sex
#  Female    9592   1179
#  Male     15128   6662

# %%
chi2_contingency(contingency_table)
# Out:
# Chi2ContingencyResult(statistic=1517.813409134445, pvalue=0.0, dof=1, expected_freq=array([[ 8177.24025675,  2593.75974325],
#        [16542.75974325,  5247.24025675]]))

# %%
# p-value < 0.05, следовательно связь между полом и уровнем дохода существует

# %%
#Ho - статистически значимая связь между полом и уровнем дохода отсутствует
contingency_table1=pd.crosstab(data['workclass'],data['class'])

# %%
contingency_table.plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
contingency_table1
# Out:
# class               <=50K   >50K
# workclass
#  ?                   1645    191
#  Federal-gov          589    371
#  Local-gov           1476    617
#  Never-worked           7      0
#  Private            17733   4963
#  Self-emp-inc         494    622
#  Self-emp-not-inc    1817    724
#  State-gov            945    353
#  Without-pay           14      0

# %%
chi2_contingency(contingency_table1)
# Out:
# Chi2ContingencyResult(statistic=1045.7085997281692, pvalue=2.026505431120716e-220, dof=8, expected_freq=array([[1.39387365e+03, 4.42126347e+02],
#        [7.28822825e+02, 2.31177175e+02],
#        [1.58898560e+03, 5.04014404e+02],
#        [5.31433310e+00, 1.68566690e+00],
#        [1.72305863e+04, 5.46541372e+03],
#        [8.47256534e+02, 2.68743466e+02],
#        [1.92910291e+03, 6.11897085e+02],
#        [9.85429194e+02, 3.12570806e+02],
#        [1.06286662e+01, 3.37133380e+00]]))

# %%
contingency_table1.plot(kind='bar')
# Out:
# <Axes: xlabel='workclass'>

# %%
contingency_table2=pd.crosstab(data['age'],data['class'])

# %%
contingency_table2
# Out:
# class   <=50K   >50K
# age
# 17        395      0
# 18        550      0
# 19        710      2
# 20        753      0
# 21        717      3
# ..        ...    ...
# 85          3      0
# 86          1      0
# 87          1      0
# 88          3      0
# 90         35      8
#
# [73 rows x 2 columns]

# %%
chi2_contingency(contingency_table2)
# Out:
# Chi2ContingencyResult(statistic=3502.0364642306, pvalue=0.0, dof=72, expected_freq=array([[2.99880225e+02, 9.51197752e+01],
#        [4.17554743e+02, 1.32445257e+02],
#        [5.40543595e+02, 1.71456405e+02],
#        [5.71670403e+02, 1.81329597e+02],
#        [5.46617119e+02, 1.73382881e+02],
#        [5.80780689e+02, 1.84219311e+02],
#        [6.65810018e+02, 2.11189982e+02],
#        [6.05833973e+02, 1.92166027e+02],
#        [6.38479162e+02, 2.02520838e+02],
#        [5.95964497e+02, 1.89035503e+02],
#        [6.33924020e+02, 2.01075980e+02],
#        [6.58218114e+02, 2.08781886e+02],
#        [6.17221830e+02, 1.95778170e+02],
#        [6.53662971e+02, 2.07337029e+02],
#        [6.74161113e+02, 2.13838887e+02],
#        [6.28609686e+02, 1.99390314e+02],
#        [6.64291637e+02, 2.10708363e+02],
#        [6.72642732e+02, 2.13357268e+02],
#        [6.65050828e+02, 2.10949172e+02],
#        [6.81753017e+02, 2.16246983e+02],
#        [6.51385400e+02, 2.06614600e+02],
# ...

# %%
contingency_table2.plot()
# Out:
# <Axes: xlabel='age'>

# %%
contingency_table3=pd.crosstab(data['education'],data['class'])

# %%
contingency_table3
# Out:
# class           <=50K   >50K
# education
#  10th             871     62
#  11th            1115     60
#  12th             400     33
#  1st-4th          162      6
#  5th-6th          317     16
#  7th-8th          606     40
#  9th              487     27
#  Assoc-acdm       802    265
#  Assoc-voc       1021    361
#  Bachelors       3134   2221
#  Doctorate        107    306
#  HS-grad         8826   1675
#  Masters          764    959
#  Preschool         51      0
#  Prof-school      153    423
#  Some-college    5904   1387

# %%
chi2_contingency(contingency_table3)
# Out:
# Chi2ContingencyResult(statistic=4429.653302288619, pvalue=0.0, dof=15, expected_freq=array([[ 708.3246829 ,  224.6753171 ],
#        [ 892.04877   ,  282.95123   ],
#        [ 328.72946163,  104.27053837],
#        [ 127.54399435,   40.45600565],
#        [ 252.81041737,   80.18958263],
#        [ 490.43702589,  155.56297411],
#        [ 390.22388747,  123.77611253],
#        [ 810.05620221,  256.94379779],
#        [1049.20119161,  332.79880839],
#        [4065.46481988, 1289.53518012],
#        [ 313.54565277,   99.45434723],
#        [7972.25883726, 2528.74116274],
#        [1308.08513252,  414.91486748],
#        [  38.71871257,   12.28128743],
#        [ 437.29369491,  138.70630509],
#        [5535.25751666, 1755.74248334]]))

# %%
contingency_table3.plot(kind='bar')
# Out:
# <Axes: xlabel='education'>

# %%
contingency_table3.plot()
# Out:
# <Axes: xlabel='education'>

# %%
contingency_table4=pd.crosstab(data['education-num'],data['class'])

# %%
contingency_table4
# Out:
# class           <=50K   >50K
# education-num
# 1                  51      0
# 2                 162      6
# 3                 317     16
# 4                 606     40
# 5                 487     27
# 6                 871     62
# 7                1115     60
# 8                 400     33
# 9                8826   1675
# 10               5904   1387
# 11               1021    361
# 12                802    265
# 13               3134   2221
# 14                764    959
# 15                153    423
# 16                107    306

# %%
chi2_contingency(contingency_table4)
# Out:
# Chi2ContingencyResult(statistic=4429.653302288619, pvalue=0.0, dof=15, expected_freq=array([[  38.71871257,   12.28128743],
#        [ 127.54399435,   40.45600565],
#        [ 252.81041737,   80.18958263],
#        [ 490.43702589,  155.56297411],
#        [ 390.22388747,  123.77611253],
#        [ 708.3246829 ,  224.6753171 ],
#        [ 892.04877   ,  282.95123   ],
#        [ 328.72946163,  104.27053837],
#        [7972.25883726, 2528.74116274],
#        [5535.25751666, 1755.74248334],
#        [1049.20119161,  332.79880839],
#        [ 810.05620221,  256.94379779],
#        [4065.46481988, 1289.53518012],
#        [1308.08513252,  414.91486748],
#        [ 437.29369491,  138.70630509],
#        [ 313.54565277,   99.45434723]]))

# %%
contingency_table4.plot()
# Out:
# <Axes: xlabel='education-num'>

# %%
contingency_table5=pd.crosstab(data['marital-status'],data['class'])

# %%
contingency_table5
# Out:
# class                    <=50K   >50K
# marital-status
#  Divorced                 3980    463
#  Married-AF-spouse          13     10
#  Married-civ-spouse       8284   6692
#  Married-spouse-absent     384     34
#  Never-married           10192    491
#  Separated                 959     66
#  Widowed                   908     85

# %%
chi2_contingency(contingency_table5)
# Out:
# Chi2ContingencyResult(statistic=6517.741653663022, pvalue=0.0, dof=6, expected_freq=array([[3.37308314e+03, 1.06991686e+03],
#        [1.74613802e+01, 5.53861982e+00],
#        [1.13696361e+04, 3.60636393e+03],
#        [3.17341605e+02, 1.00658395e+02],
#        [8.11043150e+03, 2.57256850e+03],
#        [7.78170204e+02, 2.46829796e+02],
#        [7.53876109e+02, 2.39123891e+02]]))

# %%
contingency_table5.plot(kind='bar')
# Out:
# <Axes: xlabel='marital-status'>

# %%
contingency_table6=pd.crosstab(data['race'],data['class'])

# %%
contingency_table6
# Out:
# class                 <=50K   >50K
# race
#  Amer-Indian-Eskimo     275     36
#  Asian-Pac-Islander     763    276
#  Black                 2737    387
#  Other                  246     25
#  White                20699   7117

# %%
chi2_contingency(contingency_table6)
# Out:
# Chi2ContingencyResult(statistic=330.9204310085741, pvalue=2.305960610160958e-70, dof=4, expected_freq=array([[  236.10822763,    74.89177237],
#        [  788.79886981,   250.20113019],
#        [ 2371.71094254,   752.28905746],
#        [  205.74060993,    65.25939007],
#        [21117.64135008,  6698.35864992]]))

# %%
contingency_table6.plot(kind='bar')
# Out:
# <Axes: xlabel='race'>

# %%
data.race.value_counts()
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %%
contingency_table7=pd.crosstab(data['hours-per-week'],data['class'])

# %%
contingency_table7
# Out:
# class            <=50K   >50K
# hours-per-week
# 1                   18      2
# 2                   24      8
# 3                   38      1
# 4                   51      3
# 5                   53      7
# ...                ...    ...
# 95                   1      1
# 96                   4      1
# 97                   1      1
# 98                   8      3
# 99                  60     25
#
# [94 rows x 2 columns]

# %%
chi2_contingency(contingency_table7)
# Out:
# Chi2ContingencyResult(statistic=2647.7607501671596, pvalue=0.0, dof=93, expected_freq=array([[1.51838089e+01, 4.81619115e+00],
#        [2.42940942e+01, 7.70590584e+00],
#        [2.96084273e+01, 9.39157274e+00],
#        [4.09962839e+01, 1.30037161e+01],
#        [4.55514266e+01, 1.44485734e+01],
#        [4.85881883e+01, 1.54118117e+01],
#        [1.97389515e+01, 6.26104849e+00],
#        [1.10082614e+02, 3.49173858e+01],
#        [1.36654280e+01, 4.33457203e+00],
#        [2.11054943e+02, 6.69450570e+01],
#        [8.35109487e+00, 2.64890513e+00],
#        [1.31339947e+02, 4.16600534e+01],
#        [1.74613802e+01, 5.53861982e+00],
#        [2.58124750e+01, 8.18752495e+00],
#        [3.06712939e+02, 9.72870612e+01],
#        [1.55634041e+02, 4.93659593e+01],
#        [2.20165228e+01, 6.98347717e+00],
#        [5.69392832e+01, 1.80607168e+01],
#        [1.06286662e+01, 3.37133380e+00],
#        [9.29249102e+02, 2.94750898e+02],
#        [1.82205706e+01, 5.77942938e+00],
# ...

# %%
contingency_table7.plot()
# Out:
# <Axes: xlabel='hours-per-week'>

# %%
contingency_table8=pd.crosstab(data['native-country'],data['class'])

# %%
contingency_table8
# Out:
# class                         <=50K   >50K
# native-country
#  ?                              437    146
#  Cambodia                        12      7
#  Canada                          82     39
#  China                           55     20
#  Columbia                        57      2
#  Cuba                            70     25
#  Dominican-Republic              68      2
#  Ecuador                         24      4
#  El-Salvador                     97      9
#  England                         60     30
#  France                          17     12
#  Germany                         93     44
#  Greece                          21      8
#  Guatemala                       61      3
#  Haiti                           40      4
#  Holand-Netherlands               1      0
#  Honduras                        12      1
#  Hong                            14      6
#  Hungary                         10      3
#  India                           60     40
# ...

# %%
chi2_contingency(contingency_table8)
# Out:
# Chi2ContingencyResult(statistic=317.2303857833171, pvalue=2.2113858852543023e-44, dof=41, expected_freq=array([[4.42608028e+02, 1.40391972e+02],
#        [1.44246184e+01, 4.57538159e+00],
#        [9.18620435e+01, 2.91379565e+01],
#        [5.69392832e+01, 1.80607168e+01],
#        [4.47922361e+01, 1.42077639e+01],
#        [7.21230920e+01, 2.28769080e+01],
#        [5.31433310e+01, 1.68566690e+01],
#        [2.12573324e+01, 6.74266761e+00],
#        [8.04741869e+01, 2.55258131e+01],
#        [6.83271398e+01, 2.16728602e+01],
#        [2.20165228e+01, 6.98347717e+00],
#        [1.04009091e+02, 3.29909094e+01],
#        [2.20165228e+01, 6.98347717e+00],
#        [4.85881883e+01, 1.54118117e+01],
#        [3.34043795e+01, 1.05956205e+01],
#        [7.59190443e-01, 2.40809557e-01],
#        [9.86947575e+00, 3.13052425e+00],
#        [1.51838089e+01, 4.81619115e+00],
#        [9.86947575e+00, 3.13052425e+00],
#        [7.59190443e+01, 2.40809557e+01],
# ...

# %%
contingency_table8.plot(kind='bar')
# Out:
# <Axes: xlabel='native-country'>

# %%
contingency_table8[contingency_table8.index!=' United-States'].plot(kind='bar')
# Out:
# <Axes: xlabel='native-country'>

# %%
data1=data

# %%
del data1['fnlwgt']

# %%
del data1['capital-gain']

# %%
del data1['capital-loss']

# %%
data1=pd.get_dummies(data,drop_first=True)

# %%
data1
# Out:
#        age  education-num  hours-per-week  workclass_ Federal-gov  \
# 0       39             13              40                       0
# 1       50             13              13                       0
# 2       38              9              40                       0
# 3       53              7              40                       0
# 4       28             13              40                       0
# ...    ...            ...             ...                     ...
# 32556   27             12              38                       0
# 32557   40              9              40                       0
# 32558   58              9              40                       0
# 32559   22              9              20                       0
# 32560   52              9              40                       0
#
#        workclass_ Local-gov  workclass_ Never-worked  workclass_ Private  \
# 0                         0                        0                   0
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 98 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   age                                         32561 non-null  int64
#  1   education-num                               32561 non-null  int64
#  2   hours-per-week                              32561 non-null  int64
#  3   workclass_ Federal-gov                      32561 non-null  uint8
#  4   workclass_ Local-gov                        32561 non-null  uint8
#  5   workclass_ Never-worked                     32561 non-null  uint8
#  6   workclass_ Private                          32561 non-null  uint8
#  7   workclass_ Self-emp-inc                     32561 non-null  uint8
#  8   workclass_ Self-emp-not-inc                 32561 non-null  uint8
#  9   workclass_ State-gov                        32561 non-null  uint8
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=data1
y=data1['class_ >50K']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier(max_depth = None)

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=uint8)

# %%
y_test
# Out:
# 9646     0
# 709      0
# 7385     1
# 16671    0
# 21932    0
#         ..
# 31540    0
# 18566    1
# 13141    0
# 14286    0
# 8011     0
# Name: class_ >50K, Length: 8141, dtype: uint8

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred)

# %%
precision
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[6303,    0],
#        [   0, 1838]])

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf,filled=True, class_names=True)
# Out:
# [Text(0.5, 0.75, 'x[100] <= 0.5\ngini = 0.371\nsamples = 24420\nvalue = [18417, 6003]\nclass = y[0]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 18417\nvalue = [18417, 0]\nclass = y[0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 6003\nvalue = [0, 6003]\nclass = y[1]')]
